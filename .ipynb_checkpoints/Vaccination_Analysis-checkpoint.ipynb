# %% [markdown]
# # Data Exploration

# %%
# importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pop = pd.read_csv("world_bank_pops.csv") # Source https://data.worldbank.org/indicator/SP.POP.TOTL
df_pop = pd.DataFrame(data=df_pop, columns=["Country Name", "2019 [YR2019]"])

# %%
# importing csv
df = pd.read_csv('country_vaccinations_kick_off.csv')

# %%
df = df.merge(df_pop, left_on='country', right_on='Country Name')
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.00                           0.00
# 3                            0.01                           0.01
# 4                            0.01                           0.01
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
# 3                                  NaN                            22.0
# 4                                  NaN                            23.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
# 3  Pfizer/BioNTech  Ministry of Health
# 4  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website Country Name  \
# 0  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 1  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 2  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 3  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 4  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
#
#   2019 [YR2019]
# 0       2854191
# 1       2854191
# 2       2854191
# 3       2854191
# 4       2854191

# %%
# number of rows by columns
df.shape # shape significatntly different from pre merge. Check lost data. Most likely countries with no mathcing names
# Out:
# (2730, 17)

# %%
# first 5 rows of dataset
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.00                           0.00
# 3                            0.01                           0.01
# 4                            0.01                           0.01
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
# 3                                  NaN                            22.0
# 4                                  NaN                            23.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
# 3  Pfizer/BioNTech  Ministry of Health
# 4  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website Country Name  \
# 0  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 1  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 2  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 3  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
# 4  https://shendetesia.gov.al/vaksinimi-anticovid...      Albania
#
#   2019 [YR2019]
# 0       2854191
# 1       2854191
# 2       2854191
# 3       2854191
# 4       2854191

# %%
df.tail()
# Out:
#             country iso_code        date  total_vaccinations  \
# 2725  United States      USA  2021-02-10          44769970.0
# 2726  United States      USA  2021-02-11          46390270.0
# 2727  United States      USA  2021-02-12          48410558.0
# 2728  United States      USA  2021-02-13          50641884.0
# 2729  United States      USA  2021-02-14          52884356.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 2725         33783384.0               10469514.0               1563780.0
# 2726         34723964.0               11188782.0               1620300.0
# 2727         35834855.0               12085830.0               2020288.0
# 2728         37056122.0               13082172.0               2231326.0
# 2729         38292270.0               14077440.0               2242472.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 2725           1555959.0                           13.39
# 2726           1598080.0                           13.87
# 2727           1655907.0                           14.48
# 2728           1657703.0                           15.14
# 2729           1667631.0                           15.81
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 2725                          10.10                                 3.13
# 2726                          10.38                                 3.35
# 2727                          10.71                                 3.61
# 2728                          11.08                                 3.91
# 2729                          11.45                                 4.21
#
#       daily_vaccinations_per_million                  vaccines  \
# 2725                          4652.0  Moderna, Pfizer/BioNTech
# 2726                          4778.0  Moderna, Pfizer/BioNTech
# 2727                          4951.0  Moderna, Pfizer/BioNTech
# 2728                          4957.0  Moderna, Pfizer/BioNTech
# 2729                          4986.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 2725  Centers for Disease Control and Prevention
# 2726  Centers for Disease Control and Prevention
# 2727  Centers for Disease Control and Prevention
# 2728  Centers for Disease Control and Prevention
# 2729  Centers for Disease Control and Prevention
#
#                                          source_website   Country Name  \
# 2725  https://covid.cdc.gov/covid-data-tracker/#vacc...  United States
# 2726  https://covid.cdc.gov/covid-data-tracker/#vacc...  United States
# 2727  https://covid.cdc.gov/covid-data-tracker/#vacc...  United States
# 2728  https://covid.cdc.gov/covid-data-tracker/#vacc...  United States
# 2729  https://covid.cdc.gov/covid-data-tracker/#vacc...  United States
#
#      2019 [YR2019]
# 2725     328239523
# 2726     328239523
# 2727     328239523
# 2728     328239523
# 2729     328239523

# %%
# number of na values in each field
df.isna().sum()
# Out:
# country                                   0
# iso_code                                  0
# date                                      0
# total_vaccinations                      919
# people_vaccinated                      1269
# people_fully_vaccinated                1847
# daily_vaccinations_raw                 1221
# daily_vaccinations                      110
# total_vaccinations_per_hundred          919
# people_vaccinated_per_hundred          1269
# people_fully_vaccinated_per_hundred    1847
# daily_vaccinations_per_million          110
# vaccines                                  0
# source_name                               0
# source_website                            0
# Country Name                              0
# 2019 [YR2019]                             0
# dtype: int64

# %%
# summary statistics
df.describe().round() # round function used to remove scientific notation in output
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count              1811.0             1461.0                    883.0
# mean            1381045.0          1132239.0                 385693.0
# std             4665196.0          3870553.0                1314371.0
# min                   0.0                0.0                      1.0
# 25%               24974.0            22712.0                   8366.0
# 50%              152069.0           130318.0                  40453.0
# 75%              724527.0           610383.0                 178798.0
# max            52884356.0         38292270.0               14077440.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count                  1509.0              2620.0
# mean                  73745.0             58868.0
# std                  215682.0            184981.0
# min                       0.0                 1.0
# 25%                    1575.0              1129.0
# 50%                    9250.0              5696.0
# 75%                   57909.0             29910.0
# max                 2242472.0           1916190.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                          1811.0                         1461.0
# mean                              5.0                            4.0
# std                              11.0                            8.0
# min                               0.0                            0.0
# 25%                               0.0                            0.0
# 50%                               2.0                            2.0
# 75%                               4.0                            3.0
# max                              77.0                           47.0
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                                883.0                          2620.0
# mean                                   2.0                          2084.0
# std                                    4.0                          3867.0
# min                                    0.0                             0.0
# 25%                                    0.0                           320.0
# 50%                                    1.0                           888.0
# 75%                                    1.0                          1642.0
# max                                   30.0                         30869.0

# %% [markdown]
# # Visualizations of daily trends by selected countries

# %%
def time_plot(df,feature,country):
    '''
    Plot time graphs according to a feature for certain countries
    '''
    
    plt.figure(figsize=(20,12))

    for i,country in enumerate(country):
        plt.subplot(2,4,i+1)
        data = df[df['country'] == country]
        sns.lineplot(x=data['date'] ,y=data[feature],label = feature)
        plt.tick_params(axis='x',which='both',top=False,bottom=False,labelbottom=False)

    plt.show()

# %% [markdown]
# **Trends of total_vaccinations for countries with highest total number of vaccines**

# %%
# # if desired, change the names of the list to the countries you want to plot
countries = ['United States','China','United Kingdom','England','India','Israel','Brazil','United Arab Emirates']

# plot of total_vaccinations for the countries above
time_plot(df,'total_vaccinations',countries)

# %% [markdown]
# **Trends of daily_vaccinations_raw for countries with highest total number of vaccines**

# %%
# if desired, change the names of the list to the countries you want to plot
countries = ['United States','China','United Kingdom','England','India','Israel','Brazil','United Arab Emirates']

# plot of daily_vaccinations_raw for the countries above
time_plot(df,'daily_vaccinations_raw',countries)

# %% [markdown]
# # Maximum values by country

# %% [markdown]
# Checking the maximum values of each field by country.

# %%
# group by country, then take maximum of each field, save to max_df
max_df = df.groupby(['country'])[['total_vaccinations','people_vaccinated','people_fully_vaccinated',
                        'daily_vaccinations_raw','daily_vaccinations','total_vaccinations_per_hundred',
                        'people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred',
                        'daily_vaccinations_per_million','vaccines']].max().reset_index()

# %%
# 90 countries in dataset (noted from having 90 rows in max_df)
max_df
# Out:
#                      country  total_vaccinations  people_vaccinated  \
# 0                    Albania              1127.0              689.0
# 1                    Algeria                30.0                NaN
# 2                    Andorra              1291.0             1291.0
# 3                  Argentina            609791.0           372181.0
# 4                    Austria            374034.0           242625.0
# ..                       ...                 ...                ...
# 70                    Turkey           4182027.0          3608148.0
# 71  Turks and Caicos Islands              6433.0             6433.0
# 72      United Arab Emirates           5086835.0           836568.0
# 73            United Kingdom          15839781.0         15300151.0
# 74             United States          52884356.0         38292270.0
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                     438.0                    78.0                82.0
# 1                       NaN                    30.0                30.0
# 2                       NaN                     NaN                66.0
# 3                  237610.0                 47456.0             19820.0
# 4                  143889.0                 29965.0             15156.0
# ..                      ...                     ...                 ...
# 70                 573879.0                558229.0            308326.0
# 71                      NaN                     NaN               222.0
# 72                 250000.0                284857.0            160020.0
# 73                 539630.0                609010.0            445204.0
# 74               14077440.0               2242472.0           1667631.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.04                           0.02
# 1                             0.00                            NaN
# 2                             1.67                           1.67
# 3                             1.35                           0.82
# 4                             4.15                           2.69
# ..                             ...                            ...
# 70                            4.96                           4.28
# 71                           16.62                          16.62
# 72                           51.43                           8.46
# 73                           23.33                          22.54
# 74                           15.81                          11.45
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  0.02                            28.0
# 1                                   NaN                             1.0
# 2                                   NaN                           854.0
# 3                                  0.53                           439.0
# 4                                  1.60                          1683.0
# ..                                  ...                             ...
# 70                                 0.68                          3656.0
# 71                                  NaN                          5734.0
# 72                                 2.53                         16179.0
# 73                                 0.79                          6558.0
# 74                                 4.21                          4986.0
#
#                                              vaccines
# 0                                     Pfizer/BioNTech
# 1                                           Sputnik V
# 2                                     Pfizer/BioNTech
# 3                                           Sputnik V
# 4        Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# ..                                                ...
# 70                                            Sinovac
# 71                                    Pfizer/BioNTech
# 72  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 73                Oxford/AstraZeneca, Pfizer/BioNTech
# 74                           Moderna, Pfizer/BioNTech
#
# [75 rows x 11 columns]

# %% [markdown]
# ### Total vaccinations by country

# %%
# top 25 countries with most amount of vaccinations
max_df.groupby('country')['total_vaccinations'].sum().sort_values(ascending=False)[0:25]
# Out:
# country
# United States           52884356.0
# China                   40520000.0
# United Kingdom          15839781.0
# India                    8720822.0
# Israel                   6599799.0
# Brazil                   5293979.0
# United Arab Emirates     5086835.0
# Turkey                   4182027.0
# Germany                  4146348.0
# Italy                    3044535.0
# France                   2896472.0
# Spain                    2561608.0
# Chile                    2147272.0
# Poland                   2122245.0
# Morocco                  1707091.0
# Indonesia                1578720.0
# Canada                   1258360.0
# Romania                  1151112.0
# Bangladesh               1132711.0
# Serbia                    950871.0
# Mexico                    749682.0
# Argentina                 609791.0
# Netherlands               606861.0
# Belgium                   556882.0
# Greece                    554745.0
# Name: total_vaccinations, dtype: float64

# %%
# plotting the total amount of vaccines given to countries
plt.figure(figsize=(12,3),dpi=150)
plt.title("Top 15 Countries with Total Number of Vaccines")
plt.xticks(rotation=60) # rotate x labels
plt.ticklabel_format(style='plain',axis='y')

# sort countries by total_vaccinations in descending order
plot_order = max_df.groupby('country')['total_vaccinations'].sum().sort_values(ascending=False).index.values

# plotting barplot of top 15 countries 
sns.barplot(data=max_df, x='country', y='total_vaccinations', order=plot_order[0:15]);

# %% [markdown]
# ### Total number of people vaccinated by country

# %%
# top 25 countries with most amount of people vaccinated
max_df.groupby('country')['people_vaccinated'].sum().sort_values(ascending=False)[0:25]
# Out:
# country
# United States           38292270.0
# United Kingdom          15300151.0
# Brazil                   5076110.0
# Israel                   3988763.0
# Turkey                   3608148.0
# Germany                  2736109.0
# France                   2255597.0
# Chile                    2092453.0
# Italy                    1756512.0
# Spain                    1491517.0
# Poland                   1476274.0
# Bangladesh               1132711.0
# Indonesia                1096095.0
# Canada                    922234.0
# United Arab Emirates      836568.0
# Serbia                    783161.0
# Romania                   696943.0
# Mexico                    663484.0
# Greece                    386049.0
# Argentina                 372181.0
# Belgium                   366558.0
# Sweden                    341656.0
# Hungary                   336297.0
# Portugal                  331321.0
# Bahrain                   250946.0
# Name: people_vaccinated, dtype: float64

# %%
# plotting the total amount of people vaccinated by countries
plt.figure(figsize=(12,3),dpi=150)
plt.title("Top 15 Countries with most amount of People Vaccinated")
plt.xticks(rotation=60) # rotate x labels
plt.ticklabel_format(style='plain',axis='y')

# sort countries by people_vaccinated in descending order
plot_order = max_df.groupby('country')['people_vaccinated'].sum().sort_values(ascending=False).index.values

# plotting barplot of top 15 countries 
sns.barplot(data=max_df, x='country', y='people_vaccinated', order=plot_order[0:15]);

# %% [markdown]
# ### Total number of people FULLY vaccinated by country

# %%
# top 25 countries with most amount of people vaccinated
max_df.groupby('country')['people_fully_vaccinated'].sum().sort_values(ascending=False)[0:25]
# Out:
# country
# United States           14077440.0
# Israel                   2611036.0
# Germany                  1410239.0
# Italy                    1288023.0
# Spain                    1070091.0
# Poland                    645971.0
# France                    640875.0
# Turkey                    573879.0
# United Kingdom            539630.0
# Indonesia                 482625.0
# Romania                   454169.0
# United Arab Emirates      250000.0
# Argentina                 237610.0
# Brazil                    217869.0
# Portugal                  197700.0
# Belgium                   190324.0
# Canada                    173804.0
# Greece                    168696.0
# Denmark                   168170.0
# Serbia                    167710.0
# Austria                   143889.0
# Hungary                   129339.0
# Sweden                    116206.0
# Ireland                    89999.0
# Mexico                     86198.0
# Name: people_fully_vaccinated, dtype: float64

# %%
# plotting the total amount of people fully vaccinated by countries
plt.figure(figsize=(12,3),dpi=150)
plt.title("Top 15 Countries with most amount of People Fully Vaccinated")
plt.xticks(rotation=60) # rotate x labels
plt.ticklabel_format(style='plain',axis='y')

# sort countries by people_fully_vaccinated in descending order
plot_order = max_df.groupby('country')['people_fully_vaccinated'].sum().sort_values(ascending=False).index.values

# plotting barplot of top 15 countries 
sns.barplot(data=max_df, x='country', y='people_fully_vaccinated', order=plot_order[0:15]);

# %% [markdown]
# ### Type of vaccines

# %% [markdown]
# **Number of each type of vaccine that are distributed to different countries**

# %%
# count number of vaccines given to countries (example: Pfizer/BioNTech is given to 23 countries)
max_df['vaccines'].value_counts()
# Out:
# Pfizer/BioNTech                                                                       20
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          19
# Moderna, Pfizer/BioNTech                                                               7
# Oxford/AstraZeneca                                                                     6
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    5
# Sputnik V                                                                              3
# Sinovac                                                                                2
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  2
# Sinopharm/Beijing                                                                      2
# Covaxin, Oxford/AstraZeneca                                                            1
# Pfizer/BioNTech, Sinovac                                                               1
# Oxford/AstraZeneca, Sputnik V                                                          1
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       1
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     1
# Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                          1
# Oxford/AstraZeneca, Sinovac                                                            1
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            1
# Pfizer/BioNTech, Sinopharm/Beijing                                                     1
# Name: vaccines, dtype: int64

# %%
# plotting the count of vaccines given to countries
plt.figure(figsize=(12,10),dpi=150)
plt.title("Number of Countries that each vaccine is being used")
plt.xlabel("count")

# plotting horizontal bar
max_df['vaccines'].value_counts().sort_values().plot(kind='barh');

# %% [markdown]
# Pfizer/BioNtech is the most frequently used vaccine

# %% [markdown]
# **Proportion of each vaccine given to countries**

# %%
# percentage of each vaccines
round(max_df['vaccines'].value_counts()/len(max_df) * 100,1)
# Out:
# Pfizer/BioNTech                                                                       26.7
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          25.3
# Moderna, Pfizer/BioNTech                                                               9.3
# Oxford/AstraZeneca                                                                     8.0
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    6.7
# Sputnik V                                                                              4.0
# Sinovac                                                                                2.7
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  2.7
# Sinopharm/Beijing                                                                      2.7
# Covaxin, Oxford/AstraZeneca                                                            1.3
# Pfizer/BioNTech, Sinovac                                                               1.3
# Oxford/AstraZeneca, Sputnik V                                                          1.3
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       1.3
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     1.3
# Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                          1.3
# Oxford/AstraZeneca, Sinovac                                                            1.3
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            1.3
# Pfizer/BioNTech, Sinopharm/Beijing                                                     1.3
# Name: vaccines, dtype: float64

# %% [markdown]
# # Cumulative vaccinations across dates

# %%
date_df = df[['date','daily_vaccinations_raw']].sort_values('date',ascending=True)

# %%
date_df = date_df.groupby('date')['daily_vaccinations_raw'].sum().reset_index()

# %%
date_df
# Out:
#           date  daily_vaccinations_raw
# 0   2020-12-13                     0.0
# 1   2020-12-14                     0.0
# 2   2020-12-15                     0.0
# 3   2020-12-16                     0.0
# 4   2020-12-17                     0.0
# ..         ...                     ...
# 60  2021-02-11               4674362.0
# 61  2021-02-12               5385828.0
# 62  2021-02-13               4700735.0
# 63  2021-02-14               3366069.0
# 64  2021-02-15               1713819.0
#
# [65 rows x 2 columns]

# %% [markdown]
# **Total cumulative of Daily_vaccinations_raw for all countries**

# %%
# minimum and maximum dates in dataframe
t = [df['date'].min(),df['date'].max()]

sns.lineplot(data=date_df,x='date',y='daily_vaccinations_raw')
plt.xticks(t,t)
plt.ticklabel_format(style='plain',axis='y');

# %% [markdown]
# ##
